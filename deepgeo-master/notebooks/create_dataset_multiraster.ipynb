# %% [markdown]
# # Create datasets from the geotiff images

# %%
import sys
import os
from importlib import reload

sys.path.insert(0, '../src')
import deepgeo as gf

reload(gf)
# Out:
# <module 'deepgeo' from '../src\\deepgeo\\__init__.py'>

# %%
# !pip install https://github.com/rvmaretto/deepgeo/releases/download/v0.1.0-alpha/deepgeo-0.1.0-py3-none-any.whl

# %%
DATA_DIR = os.path.join(os.path.abspath(os.path.dirname("__file__")), '../', 'data_real')
#raster_file = os.path.join(DATA_DIR, "Landsat8_225-64_17-07-2016-R6G5B4.tif")
raster_file = [os.path.join(DATA_DIR, "Landsat8_225064_17072016_R6G5B4.tif"),
               os.path.join(DATA_DIR, "Landsat8_225-64_17-07-2016-R6G5B4_radiance.tif")]
print(raster_file)
# Out:
# ['C:\\Users\\miche\\PycharmProjects\\Mestrado\\deepgeo-master\\notebooks\\../data_real\\Landsat8_225064_17072016_R6G5B4.tif', 'C:\\Users\\miche\\PycharmProjects\\Mestrado\\deepgeo-master\\notebooks\\../data_real\\Landsat8_225-64_17-07-2016-R6G5B4_radiance.tif']

# %%
img_structure = gf.generate_multi_raster_structure(raster_file, no_data=-9999)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-99cb82f14370> in <module>
# ----> 1 img_structure = gf.generate_multi_raster_structure(raster_file, no_data=-9999)
#
# AttributeError: module 'deepgeo' has no attribute 'generate_multi_raster_structure'

# %%
print(img_structure)
# Out:
# {'band_names': ['band 6 surface reflectance', 'band 5 surface reflectance', 'band 4 surface reflectance'], 'raster_arrays': [masked_array(
#   data=[[[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         ...,
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
#          [--, --, --]],
#
#         [[--, --, --],
#          [--, --, --],
#          [--, --, --],
#          ...,
#          [--, --, --],
#          [--, --, --],
# ...
